# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(18, 24))
for sp in range(0, 18):
    if (sp != 16):
        ax = fig.add_subplot(6,3,sp+1)
    else:
        continue
    if (sp % 3) == 0:
        ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp // 3]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp // 3]], c=cb_orange, label='Men', linewidth=3)
        ax.set_title(stem_cats[sp // 3])
        
        if sp == 0:
            ax.text(2005, 80, "Women")
            ax.text(2007, 16, "Men")
            
        if sp == 15:
            ax.text(2005, 10, "Women")
            ax.text(2007, 85, "Men")
            
    elif (sp % 3) == 1:
        ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp // 3]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp // 3]], c=cb_orange, label='Men', linewidth=3)
        ax.set_title(lib_arts_cats[sp // 3])
        
        if sp == 1:
            ax.text(2005, 74, "Women")
            ax.text(2007, 23, "Men")
    else:
        ax.plot(women_degrees['Year'], women_degrees[other_cats[sp // 3]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp // 3]], c=cb_orange, label='Men', linewidth=3)
        ax.set_title(other_cats[sp // 3])
        
        if sp == 2:
            ax.text(2005, 89, "Women")
            ax.text(2007, 8, "Men")
            
        if sp == 17:
            ax.text(2005, 37, "Women")
            ax.text(2007, 61, "Men")
            
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
    if sp in [13, 15, 17]:
        ax.tick_params(labelbottom="on")

plt.savefig("gender_degrees.pdf")
plt.show()

# %%
fig, ax = plt.subplots(nrows=6, ncols=3, figsize=(18,24))
fig.delaxes(ax[5,1])
col_cats = ["stem_cats", "lib_arts_cats", "other_cats"]
for row in range(6):
    for col in range(3):
            if (row == 5) & (col == 1):
                continue
            ax[row, col].plot(women_degrees['Year'], women_degrees[eval(col_cats[col])[row]], c=cb_dark_blue, label='Women', linewidth=3)
            ax[row, col].plot(women_degrees['Year'], 100-women_degrees[eval(col_cats[col])[row]], c=cb_orange, label='Men', linewidth=3)
            ax[row, col].spines["right"].set_visible(False)    
            ax[row, col].spines["left"].set_visible(False)
            ax[row, col].spines["top"].set_visible(False)    
            ax[row, col].spines["bottom"].set_visible(False)
            ax[row, col].set_xlim(1968, 2011)
            ax[row, col].set_ylim(0,100)
            ax[row, col].set_yticks([0,100])
            ax[row, col].axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
            ax[row, col].tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
            ax[row, col].set_title(eval(col_cats[col])[row])
            
            if (row == 0) & (col == 0) :
                ax[row, col].text(2005, 80, "Women")
                ax[row, col].text(2007, 16, "Men")
            
            if (row == 5) & (col == 0):
                ax[row, col].text(2005, 10, "Women")
                ax[row, col].text(2007, 85, "Men")
            
            if (row == 0) & (col == 1):
                ax[row, col].text(2005, 74, "Women")
                ax[row, col].text(2007, 23, "Men")
            
            if (row == 0) & (col == 2):
                ax[row, col].text(2005, 89, "Women")
                ax[row, col].text(2007, 8, "Men")
            
            if (row == 5) & (col == 2):
                ax[row, col].text(2005, 37, "Women")
                ax[row, col].text(2007, 61, "Men")
